# %%
# %cd ../
# Out:
# /Users/paulb/Desktop/code/research/babi

# %%
import os
import pandas as pd
from data import constants

# %% [markdown]
# # Mocap

# %%
mocap_df: pd.DataFrame = pd.read_pickle(constants.preprocessed_data_paths["mocap"])
mocap_df.head()
# Out:
#    frame  time                   AMid                         BMid  \
# 0      1  0.00  (1, 0.00000, 495.204)  (553.773, 236.266, 470.836)
# 1      2  0.01  (2, 0.01000, 495.329)  (553.676, 236.194, 470.914)
# 2      3  0.02  (3, 0.02000, 495.429)  (553.573, 236.175, 471.021)
# 3      4  0.03  (4, 0.03000, 495.505)  (553.520, 236.050, 471.109)
# 4      5  0.04  (5, 0.04000, 495.582)  (553.479, 236.036, 471.147)
#
#                           CMid                         DMid  \
# 0  (563.960, 233.489, 449.052)  (574.472, 237.092, 424.499)
# 1  (563.871, 233.477, 449.023)  (574.485, 237.102, 424.559)
# 2  (563.785, 233.509, 449.065)  (574.487, 237.096, 424.662)
# 3  (563.748, 233.494, 449.087)  (574.559, 237.001, 424.764)
# 4  (563.724, 233.560, 449.107)  (574.637, 236.976, 424.854)
#
#                           EMid                          AL1  \
# 0  (591.345, 236.356, 408.697)  (612.890, 231.029, 482.662)
# 1  (591.403, 236.236, 408.794)  (612.968, 230.860, 482.768)
# ...

# %% [markdown]
# # Capnostream

# %%
from data import plotting

# %%
import numpy as np

first_preprocessed_capnostream_file = os.listdir(os.path.join(constants.preprocessed_data_dir, "capnostream"))[1]
capnostream_file_df: pd.DataFrame = pd.read_pickle(os.path.join(constants.preprocessed_data_dir, "capnostream", first_preprocessed_capnostream_file))
print(capnostream_file_df.attrs) # show metadata
plotting.plot_capnostream_waveform(data=capnostream_file_df["co2_wave"][:200])


x = np.linspace(0, 2 * np.pi, 200)
amplitude = 15
frequency = 10
phase_shift = np.pi / 4
synthetic_data = -amplitude * np.sin(frequency * x + phase_shift) + amplitude


plotting.plot_capnostream_waveform(data=synthetic_data)
capnostream_file_df.head()
# Out:
# {'Patient ID': 'BB_003_1', 'Patient Type': 'Infant/Neonatal', 'Report Generation Time': 'Mar 10,25  08:12:56 AM', 'Date': 'Mar 10,25'}
#        time  co2_wave  et_co2  rr  group_index
# 0  08:20:00      6.60      30  73            1
# 1  08:20:00      4.57      30  73            1
# 2  08:20:00      2.57      30  73            1
# 3  08:20:00      1.95      30  73            1
# 4  08:20:00      1.78      30  73            1

# %%
capnostream_df: pd.DataFrame = pd.read_pickle(constants.preprocessed_data_paths["capnostream"])
print(capnostream_df.size) # todo: check for cases where baby did the same group twice (looking for big changes in magnitude)
print(capnostream_df.attrs)
capnostream_df.head()
# Out:
# 1424052
# ...

# %%
baby_index = 0
group_index = 0
capnostream_trial = capnostream_df[(capnostream_df["baby_index"] == baby_index) & (capnostream_df["group_index"] == group_index)]
print(f"Plotting trial (b={baby_index},g={group_index}) with {len(capnostream_trial)} ({len(capnostream_trial) / constants.capnostream_sampling_rate}s) samples")

plotting.plot_capnostream_waveform(data=capnostream_trial["co2_wave"][:100])
plotting.plot_capnostream_fourier_transform(data=capnostream_trial["co2_wave"][:100])
capnostream_trial.head()
# Out:
# Plotting trial (b=0,g=0) with 16540 (827.0s) samples
#      baby_index      time  co2_wave et_co2  rr group_index
# 9440          0  09:22:00      2.20     29  47           0
# 9441          0  09:22:00      2.18     29  47           0
# 9442          0  09:22:00      2.20     29  47           0
# 9443          0  09:22:00      2.23     29  47           0
# 9444          0  09:22:00      7.86     29  47           0

# %% [markdown]
# ### Capnostream Waveform

# %%
waveform_df: pd.DataFrame = pd.read_pickle(constants.preprocessed_data_paths["waveform"])
waveform_df.head()
# Out:
#        Time  Flat  15 HN  45 HN  15 T   45 T     CS
# 0  11:55:00  0.34  18.40   3.49  6.48  24.19   0.66
# 1  11:55:00  0.34  15.36   6.35  4.36  23.57   0.68
# 2  11:55:00  0.33  11.22  11.25  2.30  19.96   0.70
# 3  11:55:00  0.33   6.63  14.16  2.24   9.09  16.31
# 4  11:55:00  0.32   3.60  14.32  2.06   5.79  23.32

# %% [markdown]
# # Masimo

# %%
masimo_df: pd.DataFrame = pd.read_pickle(constants.preprocessed_data_paths["masimo"])
masimo_df.head()
# Out:
#        Time  SpO2 (%)  PR (bpm)  Trial Number
# 0  11:57:01        99       135             0
# 1  11:57:03        99       140             0
# 2  11:57:05        98       138             0
# 3  11:57:07        98       138             0
# 4  11:57:09        95       141             0
