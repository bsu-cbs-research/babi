# %%
# %cd ../
# Out:
# /Users/paulb/Desktop/code/research/babi

# %%
import os
import pandas as pd
from data import constants, plotting

# %% [markdown]
# # Mocap

# %%
mocap_tuples_df: pd.DataFrame = pd.read_pickle(constants.parsed_data_paths["mocap-tuples"])
mocap_tuples_df.head()
# Out:
#    frame  time                         AMid                         BMid  \
# 0      1  0.00  (495.204, 553.773, 236.266)   (470.836, 563.96, 233.489)
# 1      2  0.01  (495.329, 553.676, 236.194)  (470.914, 563.871, 233.477)
# 2      3  0.02  (495.429, 553.573, 236.175)  (471.021, 563.785, 233.509)
# 3      4  0.03    (495.505, 553.52, 236.05)  (471.109, 563.748, 233.494)
# 4      5  0.04  (495.582, 553.479, 236.036)   (471.147, 563.724, 233.56)
#
#                           CMid                         DMid  \
# 0  (449.052, 574.472, 237.092)  (424.499, 591.345, 236.356)
# 1  (449.023, 574.485, 237.102)  (424.559, 591.403, 236.236)
# 2  (449.065, 574.487, 237.096)    (424.662, 591.42, 236.14)
# 3  (449.087, 574.559, 237.001)  (424.764, 591.476, 235.963)
# 4  (449.107, 574.637, 236.976)  (424.854, 591.573, 235.841)
#
#                           EMid                          AL1  \
# 0   (408.697, 612.89, 231.029)  (482.662, 529.154, 224.304)
# 1   (408.794, 612.968, 230.86)  (482.768, 529.079, 224.239)
# 2  (408.955, 612.997, 230.738)  (482.857, 528.996, 224.234)
# 3  (409.117, 613.078, 230.472)  (483.335, 529.013, 223.264)
# 4   (409.271, 613.166, 230.27)  (483.364, 528.983, 223.255)
#
#                            AR1                          BL1  ...  \
# 0  (515.092, 577.677, 243.702)  (455.615, 543.035, 222.429)  ...
# 1  (515.144, 577.598, 243.665)   (455.687, 542.947, 222.42)  ...
# 2  (515.254, 577.499, 243.608)  (455.768, 542.855, 222.466)  ...
# 3  (515.353, 577.464, 243.496)   (455.85, 542.798, 222.397)  ...
# 4  (515.414, 577.387, 243.517)  (455.906, 542.767, 222.477)  ...
#
#                            DL1                          DR1  \
# 0  (405.754, 567.471, 218.466)  (437.616, 613.737, 241.311)
# 1   (405.746, 567.538, 218.41)   (437.651, 613.775, 241.15)
# 2   (405.809, 567.54, 218.375)  (437.757, 613.763, 241.006)
# 3  (405.539, 567.792, 218.421)  (437.851, 613.819, 240.734)
# 4   (405.581, 567.875, 218.34)  (437.947, 613.902, 240.594)
#
#                            FL1                          FR1  \
# 0  (374.572, 608.977, 207.799)  (426.942, 656.023, 223.355)
# 1  (374.642, 609.024, 207.752)  (427.131, 655.951, 223.171)
# 2  (374.762, 609.033, 207.692)  (427.368, 655.852, 222.966)
# 3   (374.871, 609.067, 207.54)   (427.56, 655.792, 222.707)
# 4  (374.979, 609.067, 207.535)  (427.766, 655.752, 222.549)
#
#                            AL2                          AR2  \
# 0  (468.759, 510.964, 198.093)   (524.99, 606.612, 238.341)
# 1  (468.776, 510.894, 197.974)  (525.025, 606.562, 238.278)
# 2  (468.797, 510.832, 198.074)  (525.113, 606.474, 238.231)
# 3  (468.952, 510.789, 197.802)  (525.219, 606.446, 238.096)
# 4    (469.0, 510.767, 197.842)  (525.306, 606.399, 238.044)
#
#                            DL2                          DR2  \
# 0  (398.532, 552.693, 194.613)   (464.848, 644.47, 232.308)
# 1  (398.639, 552.758, 194.368)  (464.844, 644.417, 232.081)
# 2  (398.663, 552.789, 194.405)  (464.856, 644.368, 231.868)
# 3  (398.771, 552.886, 194.216)   (464.88, 644.405, 231.546)
# 4  (398.801, 553.023, 194.179)  (464.901, 644.442, 231.312)
#
#                            EL2                          ER2
# 0  (377.276, 575.182, 186.727)  (454.237, 656.038, 224.052)
# 1   (377.392, 575.267, 186.65)  (454.275, 655.923, 223.763)
# 2  (377.523, 575.313, 186.627)   (454.338, 655.79, 223.444)
# 3  (377.514, 575.718, 186.933)  (454.169, 655.878, 223.768)
# 4  (377.705, 575.791, 186.787)   (454.291, 655.85, 223.421)
#
# [5 rows x 25 columns]

# %%
mocap_df: pd.DataFrame = pd.read_pickle(constants.parsed_data_paths["mocap"])
mocap_df.head()

print(mocap_df.shape)
# Out:
# (12925, 71)

# %%
import matplotlib.pyplot as plt
import numpy as np

markers = mocap_df.columns[2:]

for col in markers:
    data = mocap_df[col]
    time = np.arange(len(data)) / 100
    plt.figure(figsize=(24, 6))
    plt.plot(time, data, color='blue')
    plt.title(f'MoCap Data: {col}')
    plt.xlabel('Time (s)')
    plt.ylabel('Value')
    plt.grid(True)
    plt.savefig(f'data/out/mocap_{col}.png')

    if "z" not in col: plt.close()
# Out:
# /var/folders/r0/_whvthxx5y54lyqcvxj_53k40000gn/T/ipykernel_44483/87077472.py:9: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(24, 6))

# %% [markdown]
# # Capnostream

# %%
first_parsed_capnostream_file = os.listdir(os.path.join(constants.parsed_data_dir, "capnostream"))[4]
capnostream_file_df: pd.DataFrame = pd.read_pickle(os.path.join(constants.parsed_data_dir, "capnostream", first_parsed_capnostream_file))
print(capnostream_file_df.attrs) # show metadata
plotting.plot_capnostream_waveform(data=capnostream_file_df["co2_wave"][10000:12925])
# Out:
# {'Patient ID': 'BB_003_2', 'Patient Type': 'Infant/Neonatal', 'Report Generation Time': 'May 13,25  11:38:19 AM', 'Date': 'May 13,25'}

# %%
capnostream_df: pd.DataFrame = pd.read_pickle(constants.parsed_data_paths["capnostream"])
print(capnostream_df.size) # todo: check for cases where baby did the same group twice (looking for big changes in magnitude)
print(capnostream_df.attrs)
capnostream_df.head()
# Out:
# 1424052
# {'BB-001-1': {'Patient ID': 'BB_001_1', 'Patient Type': 'Infant/Neonatal', 'Report Generation Time': 'Jan 27,25  09:07:48 AM', 'Date': 'Jan 27,25', 'index': 0}, 'BB-005-3': {'Patient ID': 'BB_005_3', 'Patient Type': 'Infant/Neonatal', 'Report Generation Time': 'Aug 05,25  12:50:14 PM', 'Date': 'Aug 05,25', 'index': 1}, 'BB-001-3': {'Patient ID': 'BB_001_3', 'Patient Type': 'Infant/Neonatal', 'Report Generation Time': 'Apr 21,25  07:24:37 AM', 'Date': 'Apr 21,25', 'index': 2}, 'BB-005-1': {'Patient ID': 'BB_005_1', 'Patient Type': 'Infant/Neonatal', 'Report Generation Time': 'Apr 18,25  08:31:58 AM', 'Date': 'Apr 18,25', 'index': 3}, 'BB-003-2': {'Patient ID': 'BB_003_2', 'Patient Type': 'Infant/Neonatal', 'Report Generation Time': 'May 13,25  11:38:19 AM', 'Date': 'May 13,25', 'index': 4}, 'BB-005-2': {'Patient ID': 'BB_005_2', 'Patient Type': 'Infant/Neonatal', 'Report Generation Time': 'Jun 13,25  01:21:50 PM', 'Date': 'Jun 13,25', 'index': 5}, 'BB-003-1': {'Patient ID': 'BB_003_1', 'Patient Type': 'Infant/Neonatal', 'Report Generation Time': 'Mar 10,25  08:12:56 AM', 'Date': 'Mar 10,25', 'index': 6}, 'BB-002-2': {'Patient ID': 'BB_002_2', 'Patient Type': 'Infant/Neonatal', 'Report Generation Time': 'May 05,25  09:35:23 AM', 'Date': 'May 05,25', 'index': 7}, 'BB-003-3': {'Patient ID': 'BB_003_3', 'Patient Type': 'Infant/Neonatal', 'Report Generation Time': 'Jun 25,25  09:08:37 AM', 'Date': 'Jun 25,25', 'index': 8}}
#   baby_index      time  co2_wave et_co2  rr group_index
# 0          0  09:13:00     19.45     29  73           3
# 1          0  09:13:00     14.94     29  73           3
# 2          0  09:13:00      9.68     29  73           3
# 3          0  09:13:00      5.84     29  73           3
# 4          0  09:13:00      4.27     29  73           3

# %%
baby_index = 0
group_index = 0
capnostream_trial = capnostream_df[(capnostream_df["baby_index"] == baby_index) & (capnostream_df["group_index"] == group_index)]
print(f"Plotting trial (b={baby_index},g={group_index}) with {len(capnostream_trial)} ({len(capnostream_trial) / constants.capnostream_sampling_rate}s) samples")

plotting.plot_capnostream_waveform(data=capnostream_trial["co2_wave"])
capnostream_trial.head()
# Out:
# Plotting trial (b=0,g=0) with 16540 (827.0s) samples
#      baby_index      time  co2_wave et_co2  rr group_index
# 9440          0  09:22:00      2.20     29  47           0
# 9441          0  09:22:00      2.18     29  47           0
# 9442          0  09:22:00      2.20     29  47           0
# 9443          0  09:22:00      2.23     29  47           0
# 9444          0  09:22:00      7.86     29  47           0

# %% [markdown]
# ### Capnostream Waveform

# %%
waveform_df: pd.DataFrame = pd.read_pickle(constants.parsed_data_paths["waveform"])
waveform_df.head()
# Out:
#        Time  Flat  15 HN  45 HN  15 T   45 T     CS
# 0  11:55:00  0.34  18.40   3.49  6.48  24.19   0.66
# 1  11:55:00  0.34  15.36   6.35  4.36  23.57   0.68
# 2  11:55:00  0.33  11.22  11.25  2.30  19.96   0.70
# 3  11:55:00  0.33   6.63  14.16  2.24   9.09  16.31
# 4  11:55:00  0.32   3.60  14.32  2.06   5.79  23.32

# %% [markdown]
# # Capnostream & Mocap Correlation

# %%
def zscore(x: np.ndarray) -> np.ndarray:
    return (x - x.mean()) / x.std()

def cosine_similarity(a: np.ndarray, b: np.ndarray):
    a = a / np.linalg.norm(a)
    b = b / np.linalg.norm(b)
    return np.dot(a, b)

# %%
# todo: what mocap is associated with this capnostream trial?
mocap_data = mocap_df[markers[0]].values
len(mocap_data)
len(capnostream_trial["co2_wave"].values)
# Out:
# 16540

# %% [markdown]
# # Masimo

# %%
masimo_df: pd.DataFrame = pd.read_pickle(constants.parsed_data_paths["masimo"])
masimo_df.head()
# Out:
#        Time  SpO2 (%)  PR (bpm)  Trial Number
# 0  11:57:01        99       135             0
# 1  11:57:03        99       140             0
# 2  11:57:05        98       138             0
# 3  11:57:07        98       138             0
# 4  11:57:09        95       141             0
